# %% [markdown]
# # Optional SeatSense AI Exploration
#
# This notebook is intentionally lightweight. The production workflow lives in `data/generate_ticket_data.py`, `src/train_model.py`, and the Streamlit app.

# %%
import pandas as pd

df = pd.read_csv('../data/model_training_data.csv')
df.head()

# %%
df.groupby(['seat_section', 'demand_tier']).size().unstack(fill_value=0)
